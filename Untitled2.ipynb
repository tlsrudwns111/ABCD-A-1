# %% [markdown]
# <a href="https://colab.research.google.com/github/tlsrudwns111/ABCD-A-1/blob/20250328/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
삼성전자 = 50000
print(삼성전자*10)
# Out:
# 500000

# %%
시가총액 = "298조"
현재가 = "50000원"
PER = 15.79
print(시가총액, 현재가, PER)
# Out:
# 298조 50000원 15.79

# %%
a = "안녕"
b = "하세요"
print(a, b)
# Out:
# 안녕 하세요

# %%
a = 2
b = 3
print("a + a * b")
# Out:
# a + a * b
